# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi-coder439/Aditi-coder439/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:

    """Docstring of the class"""

    def __init__(self):
        # instance variables
        self.name = "Anurag"
        self.roll_no = 101
        self.marks=500

    def display(self):
        # instance method
        print("The name is:", self.name)
        print("The roll number is:", self.roll_no)
        print("The marks is:", self.marks)


# object creation
s1 = Student()

# calling method
s1.display()
# Out:
# The name is: Anurag
# The roll number is: 101
# The marks is: 500

# %%
class Student:
    def __init__(self, name, roll_no, marks):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks

    def display(self):
        print(f"The name is: {self.name}")
        print(f"The roll number is: {self.roll_no}")
        print(f"The marks is: {self.marks}")

# object creation
s2 = Student("Alice", 102, 550)

# calling method
s2.display()
